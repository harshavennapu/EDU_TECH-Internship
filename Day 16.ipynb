# %%
import json
import random
import nltk

from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data = {
    "intents": [

        {
            "tag": "greeting",
            "patterns": [
                "Hi",
                "Hello",
                "Hey"
            ],
            "responses": [
                "Hello!",
                "Hi there!"
            ]
        },
        {
            "tag": "goodbye",
            "patterns": ["Bye", "Goodbye", "See you later"],
            "responses": ["Goodbye!", "See you soon!"]
        },

        {
            "tag": "name",
            "patterns": ["What is your name?", "Who are you?"],
            "responses": ["I am an AI chatbot."]
        },

        {
            "tag": "courses",
            "patterns": [
                "What courses do you offer?",
                "Do you teach AI?",
                "Is Python course available?"
            ],
            "responses": [
                "We offer AI, ML, Python, and Data Science courses."
            ]
        },

        {
            "tag": "ai",
            "patterns": [
                "What is AI?",
                "Define artificial intelligence",
                "Explain AI",
                "Tell me about AI"
            ],
            "responses": [
                "AI stands for Artificial Intelligence."
            ]
        },

        {
            "tag": "python",
            "patterns": [
                "What is Python?",
                "Explain Python language",
                "Tell me about Python"
            ],
            "responses": [
                "Python is a popular programming language."
            ]
        },

        {
            "tag": "machine_learning",
            "patterns": [
                "What is machine learning?",
                "Explain ML",
                "Define machine learning"
            ],
            "responses": [
                "Machine Learning allows computers to learn from data."
            ]
        }
    ]
}

# %%
texts = []
labels = []

for intent in data['intents']:
    for pattern in intent['patterns']:
        texts.append(pattern)
        labels.append(intent['tag'])

print(texts)
print(labels)
# Out:
# ['Hi', 'Hello', 'Hey', 'Bye', 'Goodbye', 'See you later', 'What is your name?', 'Who are you?', 'What courses do you offer?', 'Do you teach AI?', 'Is Python course available?', 'What is AI?', 'Define artificial intelligence', 'Explain AI', 'Tell me about AI', 'What is Python?', 'Explain Python language', 'Tell me about Python', 'What is machine learning?', 'Explain ML', 'Define machine learning']
# ['greeting', 'greeting', 'greeting', 'goodbye', 'goodbye', 'goodbye', 'name', 'name', 'courses', 'courses', 'courses', 'ai', 'ai', 'ai', 'ai', 'python', 'python', 'python', 'machine_learning', 'machine_learning', 'machine_learning']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(texts)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

model.fit(X, labels)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
responses = {}

for intent in data['intents']:
    responses[intent['tag']] = intent['responses']

# %%
import random

def chatbot_response(user_text):

    user_vector = vectorizer.transform([user_text])

    prediction = model.predict(user_vector)[0]

    reply = random.choice(responses[prediction])

    return reply

# %%
chatbot_response("Hi")
# Out:
# 'Hello!'

# %%
chatbot_response("What is AI?")
# Out:
# 'AI stands for Artificial Intelligence.'

# %%
chatbot_response("What is machine learning?")
# Out:
# 'Machine Learning allows computers to learn from data.'

# %%
chatbot_response("What is Python?")
# Out:
# 'Python is a popular programming language.'

# %%
chatbot_response("What courses do you offer?")
# Out:
# 'We offer AI, ML, Python, and Data Science courses.'

# %%
chatbot_response("Who are you?")
# Out:
# 'I am an AI chatbot.'

# %%
chatbot_response("Bye")
# Out:
# 'Goodbye!'
